# %%
## exception try, except block
try:
  a=b
except:
  print("the variable has not been asigned")
# Out:
# the variable has not been asigned

# %%
## this is error we use that error of name.
try:
  a=b
except NameError as ex:
  print(ex)
# Out:
# name 'b' is not defined

# %%
## other error
try:
  result = 1/0  ## if you don't use try, except you will get the zero division error
except ZeroDivisionError as ex:
  print(ex)
  print("please enter the denominator greator than zero")
# Out:
# division by zero
# please enter the denominator greator than zero

# %%
## if there is any other error and we are using another execption it is not gonna work so but the parents work in everywhere
try:
  result = 1/0
  a/b
except ZeroDivisionError as ex: ## here this is not gonna work so you should use parent error or same errror catching
  print(ex)
  print("please enter the denominator greator than zero")
except Exception as ex1:
  print(ex)
  print("main error got caught in here")
# Out:
# division by zero
# please enter the denominator greator than zero

# %%
## how diffrent errors work in same block
try:
  num=int(input("please enter a number"))
  result=10/num
except ValueError: ## it is used when you are putting the right value
  print("that is not a valid number!")
except ZeroDivisionError:
  print("you can't divide by zero")
except Exception as ex:
  print(ex)
# Out:
# that is not a valid number!

# %%
## try, except and else block
try:
  num=int(input("please enter a number"))
  result=10/num
except ValueError:
  print("that is not a valid number!")
except ZeroDivisionError:
  print("you can't divide by zero")
except Exception as ex:
  print(ex)
else:
  print(f"the result value is {result}") ## if the value you put not get any error from the block above then this will be run
# Out:
# that is not a valid number!

# %%
## try, except, else and finally
try:
  num=int(input("please enter a number"))
  result=10/num
except ValueError:
  print("that is not a valid number!")
except ZeroDivisionError:
  print("you can't divide by zero")
except Exception as ex:
  print(ex)
else:
  print(f"the result value is {result}")
finally:
  print("execution completed") ##if error occor or not it is is gonna run in the end.
# Out:
# that is not a valid number!
# execution completed

# %%
## real example in file handling and exceptional handling
try:
  file = open('mohit.txt', 'r')
  content=file.read()
  print(content)

except FileNotFoundError:
  print("the file does not exist")

finally:
  if 'file' in locals() and not file.closed():
    file.close()
    print("file closed")
# Out:
# the file does not exist
