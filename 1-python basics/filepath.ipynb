# %%
## creat a new directory
import os
new_directory= 'sample_directoy'
os.mkdir(new_directory)
print(f"directory '{new_directory}' created")
# Out:
# directory 'sample_directoy' created

# %%
##listing files and directories
items = os.listdir('.')
print(items)
# Out:
# ['dictionaries.ipynb', 'Example.bin', 'example.csv', 'examplesfunction.ipynb', 'file.text', 'fileoperation.ipynb', 'filepath.ipynb', 'Filterfunction.ipynb', 'function.ipynb', 'lambda.ipynb', 'listExample.ipynb', 'Mapsfunction.ipynb', 'sample.txt', 'sample_directoy', 'sets.ipynb', 'smaple.txt', 'source.txt', 'standardlibrary.ipynb', 'test.ipynb', 'test_dir', 'tupals.ipynb']

# %%
## joining path
dir_name= "folder"
file_name="main.txt"
full_path=os.path.join(dir_name,file_name)
print(full_path)
# Out:
# folder\main.txt

# %%
dir_name= "folder"
file_name="main.txt"
full_path=os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# d:\data analysis\python\1-python basics\folder\main.txt

# %%
## to check path is exist or not
path='main.txt'
if os.path.exists(path):
  print(f"the path '{path}' exists")

else:
  print(f"the path '{path}' does not exists")
# Out:
# the path 'main.txt' does not exists

# %%
## checking if a path is a file or directory
import os

path= 'file.text'
if os.path.isfile(path):
  print(f"the path '{path}' is a file")
elif os.path.isdir(path):
  print(f"the path '{path}' is a directory")
else:
  print(f"the path '{path}'is neither a file nor a directory")
# Out:
# the path 'file.text' is a file

# %%
## getting the absolute path
relative_path='example.txt'
absolute_path=os.path.abspath(relative_path)
print(absolute_path)
# Out:
# d:\data analysis\python\1-python basics\example.txt

# %%
open ('exception.ipynb', 'w')
# Out:
# <_io.TextIOWrapper name='exception.ipynb' mode='w' encoding='utf-8'>
